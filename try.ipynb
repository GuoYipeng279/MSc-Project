# %%
from matplotlib import pyplot as plt
import numpy as np
import json
with open('/vol/bitbucket/yg2719/IndividualProject/humor/rew_critic_pair_sta_rela.json','r') as f:
    value_pair = json.load(f)
# plt.cla()
# plt.scatter(value_pair[:,0], value_pair[:,1], s=0.1, alpha=np.array(range(len(value_pair)))/len(value_pair))

# %%
aa = 0
len(value_pair)
value_pair[0]
# Out:
# [[1.6806442737579346,
#   -1.0395772457122803,
#   0.34817633032798767,
#   0.37333351373672485,
#   -0.7134701609611511],
#  0.2560631906781253,
#  0.01678049936890602,
#  0]

# %%
# plt.cla()
plt.figure(figsize=(10,10))
plt.xlim(-1, 6)
plt.ylim(-1, 6)
plt.autoscale(False)
value = np.array([(info[0][0], info[0][1], info[3]) for info in value_pair])
plt.scatter(value[:,0], value[:,1], alpha=1-value[:,2]/300, s=5)# alpha=np.arange(0,1,1/len(value)))
# value = np.array([(info[0][0], info[0][1], info[2]) for info in value_pair[-100:]])
# plt.scatter(value[:,0], value[:,1], alpha=np.arange(0,1,1/len(value)), c='red')
aa += 100
# for v in value: plt.text(v[0], v[1], str(round(v[2],3)))

# %%
import numpy as np
from matplotlib import pyplot as plt

a = np.array([1,2])
a.tolist()
# Out:
# [1, 2]

# %%
pose = np.load('/vol/bitbucket/yg2719/IndividualProject/humor/data/amass_processed/ACCAD/Male1General_c3d/General A1 - Stand_poses_148_frames_30_fps.npz')

# %%
plt.axis('equal')
plt.scatter(pose['joints'][0][:,1],pose['joints'][0][:,2])

# %%
print([pose[k] for k in pose])
# Out:
# ['fps', 'gender', 'floor_height', 'contacts', 'trans', 'root_orient', 'pose_body', 'pose_hand', 'betas', 'joints', 'mojo_verts', 'joints_vel', 'mojo_verts_vel', 'trans_vel', 'root_orient_vel', 'joint_orient_vel_seq', 'pose_body_vel', 'world2aligned_rot']

# %%
pose['root_orient'].shape
# Out:
# (148, 3)

# %%
import scipy.stats

degrees_of_freedom = 48
norm_threshold = 6.0

probability = scipy.stats.chi.cdf(norm_threshold, degrees_of_freedom)

# %%
probability
# Out:
# 0.10111009185570811
