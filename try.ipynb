# %%
from matplotlib import pyplot as plt
import numpy as np
import json
with open('/vol/bitbucket/yg2719/IndividualProject/humor/rew_critic_pair5.json','r') as f:
    value_pair = json.load(f)
# plt.cla()
# plt.scatter(value_pair[:,0], value_pair[:,1], s=0.1, alpha=np.array(range(len(value_pair)))/len(value_pair))

# %%
aa = 0
len(value_pair)
value_pair[0]
# Out:
# [[0.21002526581287384, 0.05251671373844147, -0.4072995185852051],
#  0.21649160981178284,
#  0.539691150188446,
#  255]

# %%
# plt.cla()
plt.figure(figsize=(10,10))
plt.xlim(-1, 6)
plt.ylim(-1, 6)
plt.autoscale(False)
value = np.array([(info[0][0], info[0][1], info[3]) for info in value_pair])
plt.scatter(value[:,0], value[:,1], alpha=1-value[:,2]/300, s=1)# alpha=np.arange(0,1,1/len(value)))
# value = np.array([(info[0][0], info[0][1], info[2]) for info in value_pair[-100:]])
# plt.scatter(value[:,0], value[:,1], alpha=np.arange(0,1,1/len(value)), c='red')
aa += 100
# for v in value: plt.text(v[0], v[1], str(round(v[2],3)))

# %%
import numpy as np
a = np.array([1,2])
a.tolist()
# Out:
# [1, 2]
