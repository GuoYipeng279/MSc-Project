# %%
from matplotlib import pyplot as plt
import numpy as np
import json
with open('/vol/bitbucket/yg2719/IndividualProject/humor/rew_critic_pair4.json','r') as f:
    value_pair = np.array(json.load(f))
plt.cla()
plt.scatter(value_pair[:,0], value_pair[:,1], alpha=np.array(range(len(value_pair)))/len(value_pair))
